# %% [markdown]
# <a href="https://colab.research.google.com/github/BrooklynZhang/Personal/blob/master/dqn_routing_multi_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/My Drive/Network Simualtor
# Out:
# /content/drive/My Drive/Network Simualtor

# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading https://files.pythonhosted.org/packages/20/f9/874b0bab83406827db93292a5bbe5acb5c18e3cea665b2f6e053292cb687/simpy-4.0.1-py2.py3-none-any.whl
# Installing collected packages: simpy
# Successfully installed simpy-4.0.1

# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np
algs = ['ant', 'q', 'dijkstra', 'dqn']

def make_total_response_time_graph(device_id, device_data_set):
    fig, ax = plt.subplots()
    plt.ylabel('transmitting time')
    plt.xlabel('packet number')
    for name in algs:
        algdataset = device_data_set[name]
        dataset = algdataset[device_id]
        data = dataset['F1']
        data.sort(key=lambda l: l[0])
        y = []
        x = [data[i][0] for i in range(0, len(data) - 5, 5)]
        #y = [data[i][1] for i in range(0, len(data), 10)]
        for j in range(0, len(data) - 5, 5):
            list = [data[i][1] for i in range(j, j + 5)]
            y.append(np.mean(list)/10)
        print(name, np.mean(y))
        ax.plot(x, y, label=name)
    ax.legend()
    plt.show()

def make_graph():
  dataset = {}
  for name in algs:
    filename = name + "dataset.txt"
    with open(filename, "rb") as FILE:
      obj = pickle.loads(FILE.read())
      iab_donor_dataset = obj.iab_donor_data
      dataset[name] = iab_donor_dataset
    FILE.close()
  make_total_response_time_graph('D1', dataset)

# %%
# !python network.py TC3.txt dijkstra
# Out:
# EVENT: The Test Case File is: TC3.txt
# EVENT: The Algorithm is: dijkstra
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: UE U1 Start Radar Routing at 0
# EVENT: UE U2 Start Radar Routing at 0
# EVENT: UE U4 Start Radar Routing at 0
# EVENT: UE U5 Start Radar Routing at 0
# EVENT: UE U6 Start Radar Routing at 0
# EVENT: UE U7 Start Radar Routing at 0
# EVENT: UE U8 Start Radar Routing at 0
# EVENT: UE U9 Start Radar Routing at 0
# EVENT: UE U10 Start Radar Routing at 0
# EVENT: UE U11 Start Radar Routing at 0
# EVENT: UE U7 receivess the Echo packet from D1 at 0.0047368
# EVENT: UE U7 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U9 receivess the Echo packet from D1 at 0.0047368
# EVENT: UE U9 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U8 receivess the Echo packet from D1 at 0.004812000000000001
# EVENT: UE U8 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U5 receivess the Echo packet from D1 at 0.007252800000000001
# EVENT: UE U5 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U6 receivess the Echo packet from D1 at 0.007355200000000001
# EVENT: UE U6 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U10 receivess the Echo packet from D1 at 0.007457600000000001
# EVENT: UE U10 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'U10']
# EVENT: UE U11 receivess the Echo packet from D1 at 0.007867200000000001
# EVENT: UE U11 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U1 receivess the Echo packet from D1 at 0.0094168
# EVENT: UE U1 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N3A', 'U1']
# EVENT: UE U4 receivess the Echo packet from D1 at 0.009768800000000001
# EVENT: UE U4 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'U4']
# EVENT: UE U2 receivess the Echo packet from D1 at 0.009956533333333333
# EVENT: UE U2 received the Echo Packet. The path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N3A', 'U2']
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: UE U1 Start Radar Routing at 5
# EVENT: UE U2 Start Radar Routing at 5
# EVENT: UE U4 Start Radar Routing at 5
# EVENT: UE U5 Start Radar Routing at 5
# EVENT: UE U6 Start Radar Routing at 5
# EVENT: UE U7 Start Radar Routing at 5
# EVENT: UE U8 Start Radar Routing at 5
# EVENT: UE U9 Start Radar Routing at 5
# EVENT: UE U10 Start Radar Routing at 5
# EVENT: UE U11 Start Radar Routing at 5
# EVENT: UE U7 receivess the Echo packet from D1 at 5.0047368000000025
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U9 receivess the Echo packet from D1 at 5.0048005333332535
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U8 receivess the Echo packet from D1 at 5.004812000000003
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U6 receivess the Echo packet from D1 at 5.008789199999921
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U5 receivess the Echo packet from D1 at 5.008993999999921
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U11 receivess the Echo packet from D1 at 5.009096399999922
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U10 receivess the Echo packet from D1 at 5.009844000000006
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N2B', 'U10']
# EVENT: UE U1 receivess the Echo packet from D1 at 5.01078213333323
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N3A', 'U1']
# EVENT: UE U2 receivess the Echo packet from D1 at 5.01103813333323
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N3A', 'U2']
# EVENT: UE U4 receivess the Echo packet from D1 at 5.0411085333332535
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N2C', 'U4']
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U1 Start Radar Routing at 10
# EVENT: UE U2 Start Radar Routing at 10
# EVENT: UE U4 Start Radar Routing at 10
# EVENT: UE U5 Start Radar Routing at 10
# EVENT: UE U6 Start Radar Routing at 10
# EVENT: UE U7 Start Radar Routing at 10
# EVENT: UE U8 Start Radar Routing at 10
# EVENT: UE U9 Start Radar Routing at 10
# EVENT: UE U10 Start Radar Routing at 10
# EVENT: UE U11 Start Radar Routing at 10
# EVENT: UE U7 receivess the Echo packet from D1 at 10.004736799999995
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U9 receivess the Echo packet from D1 at 10.004736799999995
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U8 receivess the Echo packet from D1 at 10.004811999999998
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U5 receivess the Echo packet from D1 at 10.007252799999991
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U6 receivess the Echo packet from D1 at 10.00735519999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U11 receivess the Echo packet from D1 at 10.00761119999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U10 receivess the Echo packet from D1 at 10.013279599999985
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N2B', 'U10']
# EVENT: UE U2 receivess the Echo packet from D1 at 10.01881026666656
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N2B', 'N3A', 'U2']
# EVENT: UE U1 receivess the Echo packet from D1 at 10.019083333333262
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'N2B', 'N3A', 'U1']
# EVENT: UE U4 receivess the Echo packet from D1 at 10.160652799999932
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'N2D', 'N2C', 'U4']
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U1 Start Radar Routing at 15
# EVENT: UE U2 Start Radar Routing at 15
# EVENT: UE U4 Start Radar Routing at 15
# EVENT: UE U5 Start Radar Routing at 15
# EVENT: UE U6 Start Radar Routing at 15
# EVENT: UE U7 Start Radar Routing at 15
# EVENT: UE U8 Start Radar Routing at 15
# EVENT: UE U9 Start Radar Routing at 15
# EVENT: UE U10 Start Radar Routing at 15
# EVENT: UE U11 Start Radar Routing at 15
# EVENT: UE U7 receivess the Echo packet from D1 at 15.004736799999995
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U9 receivess the Echo packet from D1 at 15.004736799999995
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U8 receivess the Echo packet from D1 at 15.005754933333316
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U5 receivess the Echo packet from D1 at 15.007252799999991
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U6 receivess the Echo packet from D1 at 15.00735519999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U10 receivess the Echo packet from D1 at 15.00745759999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'U10']
# EVENT: UE U11 receivess the Echo packet from D1 at 15.00761119999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U1 receivess the Echo packet from D1 at 15.280151466667256
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N2A', 'N3A', 'U1']
# EVENT: UE U2 receivess the Echo packet from D1 at 15.280407466667256
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N2A', 'N3A', 'U2']
# EVENT: UE U4 receivess the Echo packet from D1 at 15.281147333333363
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N2C', 'U4']
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: UE U1 Start Radar Routing at 20
# EVENT: UE U2 Start Radar Routing at 20
# EVENT: UE U4 Start Radar Routing at 20
# EVENT: UE U5 Start Radar Routing at 20
# EVENT: UE U6 Start Radar Routing at 20
# EVENT: UE U7 Start Radar Routing at 20
# EVENT: UE U8 Start Radar Routing at 20
# EVENT: UE U9 Start Radar Routing at 20
# EVENT: UE U10 Start Radar Routing at 20
# EVENT: UE U11 Start Radar Routing at 20
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U7 receivess the Echo packet from D1 at 20.004736800000007
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U9 receivess the Echo packet from D1 at 20.004736800000007
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U8 receivess the Echo packet from D1 at 20.00481200000001
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U5 receivess the Echo packet from D1 at 20.007252800000014
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U6 receivess the Echo packet from D1 at 20.007355200000013
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U11 receivess the Echo packet from D1 at 20.007611200000014
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U10 receivess the Echo packet from D1 at 20.014203333332727
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N2B', 'U10']
# EVENT: UE U4 receivess the Echo packet from D1 at 20.39458480000133
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'U4']
# EVENT: UE U1 receivess the Echo packet from D1 at 20.81452266666617
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N2B', 'N3A', 'U1']
# EVENT: UE U2 receivess the Echo packet from D1 at 20.81477866666617
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'N2A', 'N2B', 'N3A', 'U2']
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: UE U1 Start Radar Routing at 25
# EVENT: UE U2 Start Radar Routing at 25
# EVENT: UE U4 Start Radar Routing at 25
# EVENT: UE U5 Start Radar Routing at 25
# EVENT: UE U6 Start Radar Routing at 25
# EVENT: UE U7 Start Radar Routing at 25
# EVENT: UE U8 Start Radar Routing at 25
# EVENT: UE U9 Start Radar Routing at 25
# EVENT: UE U10 Start Radar Routing at 25
# EVENT: UE U11 Start Radar Routing at 25
# EVENT: UE U9 receivess the Echo packet from D1 at 25.004736800000007
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U8 receivess the Echo packet from D1 at 25.00481200000001
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U7 receivess the Echo packet from D1 at 25.005303000000012
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U5 receivess the Echo packet from D1 at 25.007252800000014
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U6 receivess the Echo packet from D1 at 25.007355200000013
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U11 receivess the Echo packet from D1 at 25.007611200000014
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U4 receivess the Echo packet from D1 at 25.00976880000002
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'U4']
# EVENT: UE U10 receivess the Echo packet from D1 at 25.012284800000028
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'N2B', 'U10']
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: UE U1 receivess the Echo packet from D1 at 26.63324266666774
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'N2B', 'N2A', 'N3A', 'U1']
# EVENT: UE U2 receivess the Echo packet from D1 at 26.63349866666774
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'N2B', 'N2A', 'N3A', 'U2']
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: UE U1 Start Radar Routing at 30
# EVENT: UE U2 Start Radar Routing at 30
# EVENT: UE U4 Start Radar Routing at 30
# EVENT: UE U5 Start Radar Routing at 30
# EVENT: UE U6 Start Radar Routing at 30
# EVENT: UE U7 Start Radar Routing at 30
# EVENT: UE U8 Start Radar Routing at 30
# EVENT: UE U9 Start Radar Routing at 30
# EVENT: UE U10 Start Radar Routing at 30
# EVENT: UE U11 Start Radar Routing at 30
# EVENT: UE U7 receivess the Echo packet from D1 at 30.004736800000007
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U8 receivess the Echo packet from D1 at 30.00481200000001
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U9 receivess the Echo packet from D1 at 30.006016533335327
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U5 receivess the Echo packet from D1 at 30.007252800000014
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U6 receivess the Echo packet from D1 at 30.007355200000013
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U11 receivess the Echo packet from D1 at 30.007636666666688
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U4 receivess the Echo packet from D1 at 30.00976880000002
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'U4']
# EVENT: UE U10 receivess the Echo packet from D1 at 30.012284800000028
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'N2B', 'U10']
# EVENT: UE U1 receivess the Echo packet from D1 at 30.01444880000004
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'N2B', 'N3A', 'U1']
# EVENT: UE U2 receivess the Echo packet from D1 at 30.01496080000004
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'N2B', 'N3A', 'U2']
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: UE U1 Start Radar Routing at 35
# EVENT: UE U2 Start Radar Routing at 35
# EVENT: UE U4 Start Radar Routing at 35
# EVENT: UE U5 Start Radar Routing at 35
# EVENT: UE U6 Start Radar Routing at 35
# EVENT: UE U7 Start Radar Routing at 35
# EVENT: UE U8 Start Radar Routing at 35
# EVENT: UE U9 Start Radar Routing at 35
# EVENT: UE U10 Start Radar Routing at 35
# EVENT: UE U11 Start Radar Routing at 35
# EVENT: UE U7 receivess the Echo packet from D1 at 35.00473679999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1A', 'U7']
# EVENT: UE U9 receivess the Echo packet from D1 at 35.00473679999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'U9']
# EVENT: UE U8 receivess the Echo packet from D1 at 35.00481199999999
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'U8']
# EVENT: UE U5 receivess the Echo packet from D1 at 35.007252799999975
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'U5']
# EVENT: UE U6 receivess the Echo packet from D1 at 35.00735519999998
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U6']
# EVENT: UE U10 receivess the Echo packet from D1 at 35.00745759999998
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'U10']
# EVENT: UE U11 receivess the Echo packet from D1 at 35.00786719999998
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2E', 'U11']
# EVENT: UE U1 receivess the Echo packet from D1 at 35.009416799999954
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N3A', 'U1']
# EVENT: UE U4 receivess the Echo packet from D1 at 35.00976879999996
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1C', 'N2D', 'N2C', 'U4']
# EVENT: UE U2 receivess the Echo packet from D1 at 35.009956533333295
# EVENT: UE Detected a quicker path. The new path to IAB-DONOR is ['D1', 'N1B', 'N2B', 'N3A', 'U2']
# EVENT: Simulation Finished

# %%
# !python network.py TC3.txt ant
# Out:
# EVENT: The Test Case File is: TC3.txt
# EVENT: The Algorithm is: ant
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: Simulation Finished

# %%
# !python network.py TC3.txt q
# Out:
# EVENT: The Test Case File is: TC3.txt
# EVENT: The Algorithm is: q
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: Simulation Finished

# %%
# !python network.py TC3.txt dqn
# Out:
# EVENT: The Test Case File is: TC3.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: N1C is currently generating neural network
# EVENT: N2E is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# WARNING: Link L13 has total packet loss of 193 at time 24
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# WARNING: Link L13 has total packet loss of 195 at time 25
# WARNING: Link L13 has total packet loss of 195 at time 26
# WARNING: Link L13 has total packet loss of 195 at time 27
# WARNING: Link L13 has total packet loss of 195 at time 28
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# WARNING: Link L13 has total packet loss of 195 at time 29
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# WARNING: Link L13 has total packet loss of 195 at time 30
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# WARNING: Link L13 has total packet loss of 195 at time 31
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# WARNING: Link L13 has total packet loss of 195 at time 32
# WARNING: Link L13 has total packet loss of 195 at time 33
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# WARNING: Link L13 has total packet loss of 195 at time 34
# WARNING: Link L13 has total packet loss of 195 at time 35
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# WARNING: Link L13 has total packet loss of 195 at time 36
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# WARNING: Link L13 has total packet loss of 195 at time 37
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# WARNING: Link L13 has total packet loss of 195 at time 38
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# WARNING: Link L13 has total packet loss of 195 at time 39
# EVENT: Simulation Finished

# %%
make_graph()
# Out:
# ant 0.10228247396149824
# q 0.2224537913894496
# dijkstra 0.5137491546640792
# dqn 0.9101661180372187

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N2E is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# WARNING: Link L14 has total packet loss of 42 at time 14
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# WARNING: Link L14 has total packet loss of 524 at time 15
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# WARNING: Link L14 has total packet loss of 1015 at time 16
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# WARNING: Link L14 has total packet loss of 1517 at time 17
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# WARNING: Link L14 has total packet loss of 2013 at time 18
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# WARNING: Link L14 has total packet loss of 2513 at time 19
# WARNING: Link L14 has total packet loss of 3006 at time 20
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# WARNING: Link L14 has total packet loss of 3493 at time 21
# WARNING: Link L14 has total packet loss of 3996 at time 22
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# WARNING: Link L14 has total packet loss of 4496 at time 23
# WARNING: Link L14 has total packet loss of 4995 at time 24
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# WARNING: Link L14 has total packet loss of 5008 at time 25
# WARNING: Link L14 has total packet loss of 5008 at time 26
# WARNING: Link L14 has total packet loss of 5008 at time 27
# WARNING: Link L14 has total packet loss of 5008 at time 28
# WARNING: Link L14 has total packet loss of 5008 at time 29
# WARNING: Link L14 has total packet loss of 5008 at time 30
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# WARNING: Link L14 has total packet loss of 5008 at time 31
# WARNING: Link L14 has total packet loss of 5008 at time 32
# WARNING: Link L14 has total packet loss of 5008 at time 33
# WARNING: Link L14 has total packet loss of 5008 at time 34
# WARNING: Link L14 has total packet loss of 5008 at time 35
# WARNING: Link L14 has total packet loss of 5008 at time 36
# WARNING: Link L14 has total packet loss of 5008 at time 37
# WARNING: Link L14 has total packet loss of 5008 at time 38
# WARNING: Link L14 has total packet loss of 5008 at time 39
# EVENT: Simulation Finished

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N1A is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N2E is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# WARNING: Link L13 has total packet loss of 295 at time 21
# WARNING: Link L13 has total packet loss of 605 at time 22
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# WARNING: Link L13 has total packet loss of 916 at time 23
# WARNING: Link L13 has total packet loss of 1223 at time 24
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# WARNING: Link L13 has total packet loss of 1223 at time 25
# WARNING: Link L13 has total packet loss of 1223 at time 26
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# WARNING: Link L13 has total packet loss of 1223 at time 27
# WARNING: Link L13 has total packet loss of 1223 at time 28
# WARNING: Link L13 has total packet loss of 1223 at time 29
# WARNING: Link L13 has total packet loss of 1223 at time 30
# WARNING: Link L13 has total packet loss of 1223 at time 31
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# WARNING: Link L13 has total packet loss of 1223 at time 32
# WARNING: Link L13 has total packet loss of 1223 at time 33
# WARNING: Link L13 has total packet loss of 1223 at time 34
# WARNING: Link L13 has total packet loss of 1223 at time 35
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# WARNING: Link L13 has total packet loss of 1223 at time 36
# WARNING: Link L13 has total packet loss of 1223 at time 37
# WARNING: Link L13 has total packet loss of 1223 at time 38
# WARNING: Link L13 has total packet loss of 1223 at time 39
# EVENT: Simulation Finished

# %%
make_graph()
# Out:
# ant 0.10228247396149824
# q 0.2224537913894496
# dijkstra 0.5137491546640792
# dqn 1.013432066350115

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N2A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N1A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N1B is currently generating neural network
# EVENT: N2E is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# WARNING: Link L14 has total packet loss of 76 at time 16
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# WARNING: Link L14 has total packet loss of 76 at time 17
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# WARNING: Link L14 has total packet loss of 76 at time 18
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# WARNING: Link L14 has total packet loss of 76 at time 19
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# WARNING: Link L14 has total packet loss of 76 at time 20
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# WARNING: Link L14 has total packet loss of 76 at time 21
# WARNING: Link L14 has total packet loss of 76 at time 22
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# WARNING: Link L14 has total packet loss of 76 at time 23
# WARNING: Link L14 has total packet loss of 76 at time 24
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# WARNING: Link L14 has total packet loss of 76 at time 25
# WARNING: Link L14 has total packet loss of 76 at time 26
# WARNING: Link L14 has total packet loss of 76 at time 27
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# WARNING: Link L14 has total packet loss of 76 at time 28
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# WARNING: Link L14 has total packet loss of 76 at time 29
# WARNING: Link L14 has total packet loss of 76 at time 30
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# WARNING: Link L14 has total packet loss of 76 at time 31
# WARNING: Link L14 has total packet loss of 76 at time 32
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# WARNING: Link L14 has total packet loss of 76 at time 33
# WARNING: Link L14 has total packet loss of 76 at time 34
# WARNING: Link L14 has total packet loss of 76 at time 35
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# WARNING: Link L14 has total packet loss of 76 at time 36
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# WARNING: Link L14 has total packet loss of 76 at time 37
# WARNING: Link L14 has total packet loss of 76 at time 38
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# WARNING: Link L14 has total packet loss of 76 at time 39
# EVENT: Simulation Finished

# %%
make_graph()
# Out:
# ant 0.10228247396149824
# q 0.2224537913894496
# dijkstra 0.5137491546640792
# dqn 1.1651392340628037

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: N2E is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# WARNING: Link L13 has total packet loss of 18 at time 20
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# WARNING: Link L13 has total packet loss of 326 at time 21
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# WARNING: Link L13 has total packet loss of 629 at time 22
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# WARNING: Link L13 has total packet loss of 936 at time 23
# WARNING: Link L13 has total packet loss of 1252 at time 24
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# WARNING: Link L13 has total packet loss of 1254 at time 25
# WARNING: Link L13 has total packet loss of 1254 at time 26
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# WARNING: Link L13 has total packet loss of 1254 at time 27
# WARNING: Link L13 has total packet loss of 1254 at time 28
# WARNING: Link L13 has total packet loss of 1254 at time 29
# WARNING: Link L13 has total packet loss of 1254 at time 30
# WARNING: Link L13 has total packet loss of 1254 at time 31
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# WARNING: Link L13 has total packet loss of 1254 at time 32
# WARNING: Link L13 has total packet loss of 1254 at time 33
# WARNING: Link L13 has total packet loss of 1254 at time 34
# WARNING: Link L13 has total packet loss of 1254 at time 35
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# WARNING: Link L13 has total packet loss of 1254 at time 36
# WARNING: Link L13 has total packet loss of 1254 at time 37
# WARNING: Link L13 has total packet loss of 1254 at time 38
# WARNING: Link L13 has total packet loss of 1254 at time 39
# EVENT: Simulation Finished

# %%
make_graph()
# Out:
# ant 0.10228247396149824
# q 0.2224537913894496
# dijkstra 0.5137491546640792
# dqn 1.0262819824434042

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N2A is currently generating neural network
# EVENT: N2E is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# WARNING: Link L14 has total packet loss of 221 at time 16
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# WARNING: Link L14 has total packet loss of 629 at time 17
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# WARNING: Link L14 has total packet loss of 1039 at time 18
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# WARNING: Link L14 has total packet loss of 1039 at time 19
# WARNING: Link L14 has total packet loss of 1039 at time 20
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# WARNING: Link L14 has total packet loss of 1039 at time 21
# WARNING: Link L14 has total packet loss of 1039 at time 22
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# WARNING: Link L14 has total packet loss of 1039 at time 23
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# WARNING: Link L14 has total packet loss of 1039 at time 24
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# WARNING: Link L14 has total packet loss of 1039 at time 25
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# WARNING: Link L14 has total packet loss of 1039 at time 26
# WARNING: Link L14 has total packet loss of 1039 at time 27
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# WARNING: Link L14 has total packet loss of 1039 at time 28
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# WARNING: Link L14 has total packet loss of 1039 at time 29
# WARNING: Link L14 has total packet loss of 1039 at time 30
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# WARNING: Link L14 has total packet loss of 1039 at time 31
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# WARNING: Link L14 has total packet loss of 1039 at time 32
# WARNING: Link L14 has total packet loss of 1039 at time 33
# WARNING: Link L14 has total packet loss of 1039 at time 34
# WARNING: Link L14 has total packet loss of 1039 at time 35
# WARNING: Link L14 has total packet loss of 1039 at time 36
# WARNING: Link L14 has total packet loss of 1039 at time 37
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# WARNING: Link L14 has total packet loss of 1039 at time 38
# WARNING: Link L14 has total packet loss of 1039 at time 39
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: Simulation Finished

# %%
make_graph()
# Out:
# ant 0.10228247396149824
# q 0.2224537913894496
# dijkstra 0.5137491546640792
# dqn 1.2196517421574466

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N1C is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N2E is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N1B is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# WARNING: Link L13 has total packet loss of 304 at time 21
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# WARNING: Link L13 has total packet loss of 609 at time 22
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# WARNING: Link L13 has total packet loss of 915 at time 23
# WARNING: Link L13 has total packet loss of 1219 at time 24
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# WARNING: Link L13 has total packet loss of 1219 at time 25
# WARNING: Link L13 has total packet loss of 1219 at time 26
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# WARNING: Link L13 has total packet loss of 1219 at time 27
# WARNING: Link L13 has total packet loss of 1219 at time 28
# WARNING: Link L13 has total packet loss of 1219 at time 29
# WARNING: Link L13 has total packet loss of 1219 at time 30
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# WARNING: Link L13 has total packet loss of 1219 at time 31
# WARNING: Link L13 has total packet loss of 1219 at time 32
# WARNING: Link L13 has total packet loss of 1219 at time 33
# WARNING: Link L13 has total packet loss of 1219 at time 34
# WARNING: Link L13 has total packet loss of 1219 at time 35
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# WARNING: Link L13 has total packet loss of 1219 at time 36
# WARNING: Link L13 has total packet loss of 1219 at time 37
# WARNING: Link L13 has total packet loss of 1219 at time 38
# WARNING: Link L13 has total packet loss of 1219 at time 39
# EVENT: Simulation Finished

# %%
make_graph()
# Out:
# ant 0.10228247396149824
# q 0.2224537913894496
# dijkstra 0.5137491546640792
# dqn 1.0174878496414392

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N2E is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: Simulation Finished

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N1C is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N1A is currently generating neural network
# EVENT: N2E is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: Simulation Finished

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N2A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N1C is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N2E is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: Simulation Finished

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N2E is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N1C is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N1A is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: Simulation Finished

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: N1A is currently generating neural network
# EVENT: N2E is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: Simulation Finished

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N2A is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: N2E is currently generating neural network
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: Simulation Finished

# %%
# !python network.py TC4.txt dqn
# Out:
# EVENT: The Test Case File is: TC4.txt
# EVENT: The Algorithm is: dqn
# EVENT: Time List is deque([1.0, 3.0, 2.0, 0.0, 1.5, 1.0, 0.0, 0.5, 0.0, 0.5, 1.0, 1.5, 2.0])
# EVENT: Adding flow to UE U1 at 4.0
# EVENT: UE U1 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U2 at 4.0
# EVENT: UE U2 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: Adding flow to UE U4 at 4.0
# EVENT: UE U4 Send DataPacket 0 / 5000 to D1 at 4.0
# EVENT: N3A is currently generating neural network
# EVENT: N2C is currently generating neural network
# EVENT: N2B is currently generating neural network
# EVENT: N2A is currently generating neural network
# EVENT: N2D is currently generating neural network
# EVENT: N1B is currently generating neural network
# EVENT: N1C is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 0
# EVENT: N2E is currently generating neural network
# EVENT: N1A is currently generating neural network
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 0
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 0
# EVENT: UE U1 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U2 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: UE U4 Send DataPacket 500 / 5000 to D1 at 5.99999999999978
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 500
# EVENT: UE U1 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U2 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: UE U4 Send DataPacket 1000 / 5000 to D1 at 7.9999999999995595
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1000
# EVENT: UE U1 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U2 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: UE U4 Send DataPacket 1500 / 5000 to D1 at 9.99999999999934
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 1500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 1500
# EVENT: UE U1 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U2 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: UE U4 Send DataPacket 2000 / 5000 to D1 at 11.999999999999119
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2000
# EVENT: UE U1 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U2 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: UE U4 Send DataPacket 2500 / 5000 to D1 at 13.999999999998899
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 2500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 2500
# EVENT: UE U1 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U2 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: UE U4 Send DataPacket 3000 / 5000 to D1 at 15.999999999998678
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3000
# EVENT: UE U1 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U2 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: UE U4 Send DataPacket 3500 / 5000 to D1 at 17.999999999999346
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3000
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 3500
# EVENT: UE U1 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U2 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: UE U4 Send DataPacket 4000 / 5000 to D1 at 20.000000000000014
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 3500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4000
# EVENT: UE U1 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U2 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: UE U4 Send DataPacket 4500 / 5000 to D1 at 22.000000000000682
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4000
# EVENT: UE U1 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U2 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: UE U4 Send DataPacket 5000 / 5000 to D1 at 24.00000000000135
# EVENT: All The Data Packet of Flow Id F1 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F2 Has Been Sent, It Will Have No Ack Packet
# EVENT: All The Data Packet of Flow Id F3 Has Been Sent, It Will Have No Ack Packet
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U4 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 4500
# EVENT: IAB Donor D1 received the data packet from U2 with packet id of 5000
# EVENT: IAB Donor D1 received the data packet from U1 with packet id of 5000
# EVENT: Simulation Finished

# %%
make_graph()
# Out:
# ant 0.10228247396149824
# q 0.2224537913894496
# dijkstra 0.5137491546640792
# dqn 0.143362269757445
