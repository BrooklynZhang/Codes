# %% [markdown]
# <a href="https://colab.research.google.com/github/BrooklynZhang/Personal/blob/master/nlp_extra_credit_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import numpy as np
import json
import os
import re

labels = ["anger", "anticipation", "disgust", "fear", "joy", "love", "optimism", "pessimism", "sadness", "surprise", "trust", "neutral"]
batch_size = 64
buffer_size = 1024
save_path = "model/"
encoder_file = save_path + "encoder"


def load_data(jsonfile, labels):
    data = []
    result = []
    with open(jsonfile, "r") as data_file:
        dataset = json.load(data_file)
        for id, post in dataset.items():
            doc = post["body"]
            labellist = []
            for tag in labels:
                labellist.append(int(post["emotion"][tag]))

            data.append(doc)
            result.append(labellist)
    result = np.asarray(result, dtype=np.int64)
    dataset = tf.data.Dataset.from_tensor_slices((data, result))
    return dataset


def create_model(encoder=None):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(encoder.vocab_size, 64),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(len(labels))
    ])
    return model

if __name__ == "__main__":

    if not os.path.exists(save_path):
        os.makedirs(save_path)

    post_dataset = load_data("nlp_train.json", labels)

    tokenizer = tfds.features.text.Tokenizer()
    vocabulary_set = set()
    for text_tensor, _ in post_dataset:
        tokens = tokenizer.tokenize(text_tensor.numpy())
        vocabulary_set.update(tokens)

    load_model = True

    if load_model:
        print("Loading model from {}".format(save_path))
        model = tf.keras.models.load_model(save_path)
        encoder = tfds.features.text.TokenTextEncoder.load_from_file(encoder_file)
    else:
        encoder = tfds.features.text.TokenTextEncoder(vocabulary_set)
        model = create_model(encoder=encoder)
        encoder.save_to_file(encoder_file)

    def encode_map_fn(text, label): #encode the text to integers
        def encode(text_tensor, label):
            encoded_text = encoder.encode(text_tensor.numpy())
            return encoded_text, label

        encoded_text, label = tf.py_function(encode, inp=[text, label], Tout=(tf.int64, tf.int64))

        encoded_text.set_shape([None])
        label.set_shape([None])
        return encoded_text, label

    dataset_encoded = post_dataset.map(encode_map_fn)

    x_test = dataset_encoded.take(100)
    x_test = x_test.padded_batch(batch_size, padded_shapes=([None],[None]))
    
    x_train = dataset_encoded.skip(100).shuffle(buffer_size)
    x_train = x_train.padded_batch(batch_size, padded_shapes=([None],[None]))

    model.compile(loss=tf.keras.losses.MeanSquaredError(), metrics=["accuracy"], optimizer=tf.keras.optimizers.Adam(1e-4))

    for i in range(10):
        history = model.fit(x_train, epochs=10, batch_size=batch_size, validation_data=x_test)
        tf.keras.models.save_model(model, save_path)
# Out:
# Dataset size: 1493
# Vocabulary size: 37371
# Loading model from model/
# Epoch 1/10
# 22/22 [==============================] - 5s 218ms/step - loss: 0.0458 - accuracy: 0.3460 - val_loss: 0.1988 - val_accuracy: 0.2300
# Epoch 2/10
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0419 - accuracy: 0.3482 - val_loss: 0.1984 - val_accuracy: 0.2200
# Epoch 3/10
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0405 - accuracy: 0.3532 - val_loss: 0.1994 - val_accuracy: 0.2300
# Epoch 4/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0398 - accuracy: 0.3568 - val_loss: 0.2006 - val_accuracy: 0.2200
# Epoch 5/10
# 22/22 [==============================] - 4s 178ms/step - loss: 0.0393 - accuracy: 0.3553 - val_loss: 0.2010 - val_accuracy: 0.2400
# Epoch 6/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0388 - accuracy: 0.3726 - val_loss: 0.2023 - val_accuracy: 0.2200
# Epoch 7/10
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0384 - accuracy: 0.3431 - val_loss: 0.2039 - val_accuracy: 0.2100
# Epoch 8/10
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0380 - accuracy: 0.3518 - val_loss: 0.2034 - val_accuracy: 0.2300
# Epoch 9/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0374 - accuracy: 0.3546 - val_loss: 0.2042 - val_accuracy: 0.2300
# Epoch 10/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0370 - accuracy: 0.3467 - val_loss: 0.2044 - val_accuracy: 0.2400
# INFO:tensorflow:Assets written to: model/assets
# Epoch 1/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0364 - accuracy: 0.3611 - val_loss: 0.2056 - val_accuracy: 0.2200
# Epoch 2/10
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0362 - accuracy: 0.3582 - val_loss: 0.2051 - val_accuracy: 0.2200
# Epoch 3/10
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0358 - accuracy: 0.3431 - val_loss: 0.2058 - val_accuracy: 0.2300
# Epoch 4/10
# 22/22 [==============================] - 4s 179ms/step - loss: 0.0353 - accuracy: 0.3604 - val_loss: 0.2065 - val_accuracy: 0.2200
# Epoch 5/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0347 - accuracy: 0.3625 - val_loss: 0.2055 - val_accuracy: 0.2000
# Epoch 6/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0344 - accuracy: 0.3611 - val_loss: 0.2074 - val_accuracy: 0.2300
# Epoch 7/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0337 - accuracy: 0.3654 - val_loss: 0.2076 - val_accuracy: 0.2200
# Epoch 8/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0332 - accuracy: 0.3604 - val_loss: 0.2080 - val_accuracy: 0.2000
# Epoch 9/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0327 - accuracy: 0.3460 - val_loss: 0.2105 - val_accuracy: 0.2600
# Epoch 10/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0324 - accuracy: 0.3733 - val_loss: 0.2090 - val_accuracy: 0.2000
# INFO:tensorflow:Assets written to: model/assets
# Epoch 1/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0320 - accuracy: 0.3510 - val_loss: 0.2110 - val_accuracy: 0.2400
# Epoch 2/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0320 - accuracy: 0.3625 - val_loss: 0.2085 - val_accuracy: 0.2600
# Epoch 3/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0313 - accuracy: 0.3654 - val_loss: 0.2092 - val_accuracy: 0.2200
# Epoch 4/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0306 - accuracy: 0.3604 - val_loss: 0.2099 - val_accuracy: 0.2300
# Epoch 5/10
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0301 - accuracy: 0.3661 - val_loss: 0.2111 - val_accuracy: 0.2100
# Epoch 6/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0297 - accuracy: 0.3518 - val_loss: 0.2117 - val_accuracy: 0.2200
# Epoch 7/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0295 - accuracy: 0.3683 - val_loss: 0.2117 - val_accuracy: 0.2200
# Epoch 8/10
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0292 - accuracy: 0.3561 - val_loss: 0.2108 - val_accuracy: 0.2200
# Epoch 9/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0288 - accuracy: 0.3589 - val_loss: 0.2124 - val_accuracy: 0.2300
# Epoch 10/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0283 - accuracy: 0.3525 - val_loss: 0.2110 - val_accuracy: 0.2200
# INFO:tensorflow:Assets written to: model/assets
# Epoch 1/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0281 - accuracy: 0.3532 - val_loss: 0.2125 - val_accuracy: 0.2000
# Epoch 2/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0279 - accuracy: 0.3632 - val_loss: 0.2108 - val_accuracy: 0.2300
# Epoch 3/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0273 - accuracy: 0.3561 - val_loss: 0.2126 - val_accuracy: 0.2200
# Epoch 4/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0267 - accuracy: 0.3589 - val_loss: 0.2121 - val_accuracy: 0.2100
# Epoch 5/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0263 - accuracy: 0.3525 - val_loss: 0.2127 - val_accuracy: 0.2200
# Epoch 6/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0259 - accuracy: 0.3553 - val_loss: 0.2145 - val_accuracy: 0.2200
# Epoch 7/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0256 - accuracy: 0.3518 - val_loss: 0.2140 - val_accuracy: 0.2200
# Epoch 8/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0255 - accuracy: 0.3575 - val_loss: 0.2139 - val_accuracy: 0.2200
# Epoch 9/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0254 - accuracy: 0.3568 - val_loss: 0.2145 - val_accuracy: 0.2000
# Epoch 10/10
# 22/22 [==============================] - 4s 180ms/step - loss: 0.0251 - accuracy: 0.3546 - val_loss: 0.2135 - val_accuracy: 0.2200
# INFO:tensorflow:Assets written to: model/assets
# Epoch 1/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0248 - accuracy: 0.3510 - val_loss: 0.2147 - val_accuracy: 0.2200
# Epoch 2/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0244 - accuracy: 0.3668 - val_loss: 0.2140 - val_accuracy: 0.2200
# Epoch 3/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0240 - accuracy: 0.3396 - val_loss: 0.2156 - val_accuracy: 0.2500
# Epoch 4/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0236 - accuracy: 0.3604 - val_loss: 0.2152 - val_accuracy: 0.2200
# Epoch 5/10
# 22/22 [==============================] - 4s 182ms/step - loss: 0.0232 - accuracy: 0.3396 - val_loss: 0.2151 - val_accuracy: 0.2300
# Epoch 6/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0230 - accuracy: 0.3482 - val_loss: 0.2152 - val_accuracy: 0.2400
# Epoch 7/10
# 22/22 [==============================] - 4s 186ms/step - loss: 0.0227 - accuracy: 0.3510 - val_loss: 0.2154 - val_accuracy: 0.2300
# Epoch 8/10
# 22/22 [==============================] - 4s 181ms/step - loss: 0.0224 - accuracy: 0.3532 - val_loss: 0.2148 - val_accuracy: 0.2200
# Epoch 9/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0223 - accuracy: 0.3568 - val_loss: 0.2160 - val_accuracy: 0.2300
# Epoch 10/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0225 - accuracy: 0.3439 - val_loss: 0.2154 - val_accuracy: 0.2300
# INFO:tensorflow:Assets written to: model/assets
# Epoch 1/10
# 22/22 [==============================] - 4s 185ms/step - loss: 0.0223 - accuracy: 0.3309 - val_loss: 0.2160 - val_accuracy: 0.2400
# Epoch 2/10
# 22/22 [==============================] - 4s 183ms/step - loss: 0.0221 - accuracy: 0.3460 - val_loss: 0.2158 - val_accuracy: 0.2500
# Epoch 3/10
# 22/22 [==============================] - 4s 184ms/step - loss: 0.0217 - accuracy: 0.3417 - val_loss: 0.2136 - val_accuracy: 0.2500
# Epoch 4/10
# 22/22 [==============================] - 4s 187ms/step - loss: 0.0213 - accuracy: 0.3460 - val_loss: 0.2145 - val_accuracy: 0.2200
# Epoch 5/10
#  4/22 [====>.........................] - ETA: 3s - loss: 0.0201 - accuracy: 0.3633
